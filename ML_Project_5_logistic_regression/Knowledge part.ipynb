# %% [markdown]
# # This part I am learning logistic regression.
# 1. Definition of logistic regression
# 2. From Linear Regression to Logistic Regression—The Introduction of the Logistic Function
# 3. Using Logistic Regression to Solve Binary or Multiclass Classification Problems
# 4. Underfitting and Overfitting in Machine Learning and How to Solve Overfitting Problems Through Regularization
#
# # All features must be converted into numerical form in order to be recognized by a machine; this process is also known as feature engineering.
#
# ## sigmoid function is continue function. The sigmoid function is differentiable; it is a convex function and has a global minimum.
#
# # In logistic regression, MSE cannot be used. This is because, after being transformed by a logistic function, MSE is no longer a convex function with respect to w and b; as a result, it is impossible to find the global minimum using gradient descent.
# # Then we can use sigmoid function to do gradient descent in logistic function.
